# %% [markdown]
# <h1><u>Ejercicio "Diagramas de flujo II"</u></h1>
# <span>ID del ejercicio: 83 - theEgg AI</span>

# %%
lado_cuadrado = int(input("Introduce el tamaño del lado de un cuadrado: "))
print(f"La superficie del cuadrado es: {(lado_cuadrado * lado_cuadrado)}")
# Out:
# Introduce el tamaño del lado de un cuadrado: 4
# La superficie del cuadrado es: 16
